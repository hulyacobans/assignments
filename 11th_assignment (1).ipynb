# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics
import pandas as pd

# %%
örneklem = []
örneklem_ortalamaları = []
for deneme in range(1,50):
    atış = np.random.normal(40, 5, 1000)
    örneklem.append(atış)
    örneklem_ortalamaları.append(np.mean(örneklem))

# %%
print(np.mean(örneklem))
print(np.mean(örneklem_ortalamaları))
# Out:
# 39.99494804961849
# 39.96614142219076

# %%
plt.figure(figsize=(8,4))
plt.subplot(1, 2, 1)
plt.hist(örneklem, bins=80)
plt.title('örneklem')
plt.xlabel('Rastgele Değerler')

plt.subplot(1, 2, 2)
plt.hist(örneklem_ortalamaları, bins=80)
plt.title('örneklem ortalamaları 50')
plt.xlabel('Rastgele Değerler')
plt.show()

# %%
örneklem2 = []
örneklem_ortalamaları2 = []
for deneme2 in range(1,1000):
    atış = np.random.normal(70, 5, 1000)
    örneklem2.append(atış)
    örneklem_ortalamaları2.append(np.mean(örneklem2))

# %%
print(np.mean(örneklem2))
print(np.mean(örneklem_ortalamaları2))
# Out:
# 70.00623397505387
# 70.0045718744358

# %%
plt.figure(figsize=(8,4))
plt.subplot(1, 2, 1)
plt.hist(örneklem2, bins=40)
plt.title('örneklem 2')
plt.xlabel('Rastgele Değerler')

plt.subplot(1, 2, 2)
plt.hist(örneklem_ortalamaları2, bins=40)
plt.title('örneklem ortalamaları 1000')
plt.xlabel('Rastgele Değerler')
plt.show()

# %%
# Ödev 2
# n kez atılacak deniliyorsa, yani çokça tekrar edecekse bu döngü, bir yerden sonra ortalamaya yaklaşacaktır.
# yani bu durumda herhangi birini seçtiğimde gelen ortalamaya göre uzun vadede gelecek tura sayısını tahmin edebilirim.

# çok sayıda deneme yapıldığında da yine fair olan ile fair olmayanın ortalamasından dolayı tahmin edebilirim gibi
#geliyor :)
